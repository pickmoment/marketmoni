# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import dateutil.parser
import pytz

# %matplotlib inline

# %%
d = {'TEST': [123, 222]}
next(iter(d.values()))[0]
# Out:
# 123

# %%
headers = {'user-agent': 'Mozilla/5.0'}

def get(url):
    return requests.get(url, headers=headers).json()

def get_codes():
    url = 'https://crix-api-endpoint.upbit.com/v1/crix/trends/acc_trade_price_24h?includeNonactive=false&codeOnly=true'
    return get(url)

def get_pair(code):
    pair = code.split('.')[-1].lower().replace('-', '_')
    return pair

def get_utc(dt):
    dt = dt.tz_localize('Asia/Seoul')
    return dt.tz_convert('UTC').strftime('%Y-%m-%d %H:%M:%S')

# %%
def get_minute_candles(code, minute=1, count=200, to=None):
    url = 'https://crix-api-endpoint.upbit.com/v1/crix/candles/minutes/{}?code={}&count={}'.format(minute, code, count)
    if to:
        url += '&to={}'.format(to)
    cols = ['candleDateTimeKst','openingPrice','tradePrice','lowPrice','highPrice',
            'candleAccTradePrice','candleAccTradeVolume', ]
    data = get(url)
    df = pd.DataFrame(data, columns=cols)
    df['candleDateTimeKst'] = pd.to_datetime(df['candleDateTimeKst']) + pd.Timedelta('09:00:00')
    df = df.rename(columns = {
        'candleAccTradePrice': 'acc_price',
        'candleAccTradeVolume': 'acc_vol',
        'candleDateTime': 'dt',
        'candleDateTimeKst': 'dt_kst',
        'highPrice': 'high',
        'lowPrice': 'low',
        'openingPrice': 'open',
        'tradePrice': 'close'
    })
    df = df.set_index('dt_kst')
    df = df.sort_index()
    return df

# %%
def bollinger_band(df, period, times):
    top = df['close'].rolling(window=period).mean() + (df['close'].rolling(window=period).std() * times)
    mid = df['close'].rolling(window=period).mean()
    btm = df['close'].rolling(window=period).mean() - (df['close'].rolling(window=period).std() * times)   
    bollinger = {'top': top, 'mid': mid, 'bottom': btm}
    return bollinger

def eye_balance(df):
    base = (df['low'].rolling(window=26).min() + df['high'].rolling(window=26).max()) / 2
    trans = (df['low'].rolling(window=9).min() + df['high'].rolling(window=9).max()) / 2
    fore1 = ((base + trans) / 2).shift(25)
    fore2 = ((df['low'].rolling(window=52).min() + df['high'].rolling(window=52).max()) / 2).shift(25)   
    eye = {'base': base, 'trans': trans, 'fore1': fore1, 'fore2': fore2}
    return eye

def sma(df, period):
    return df['close'].rolling(window=period).mean()
    
def ema(df, period):
    return df['close'].ewm(span=period, min_periods=period).mean()

# %%
from pandas.io import sql
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://crypto:cryptomoon@localhost/crypto_currency')

def get_table_name(code, minute):
    table_name = 'upbit_minutes_{}_{}'.format(minute, get_pair(code))
    return table_name

def read_data(table_name, start_date=None, end_date=None):
    sql = "select * from {}".format(table_name)
    where = []
    if start_date:
        where.append("dt_kst >= '{}'".format(start_date))
    if end_date:
        where.append("dt_kst <= '{}'".format(end_date))
    if where:
        sql += ' where ' + 'and '.join(where)
        
    print(sql)
    df = pd.read_sql(sql, engine, index_col='dt_kst')
    return df

def insert_data(df, table_name):
    df.to_sql(con=engine, name=table_name, if_exists='append')
    
def create_table(df, table_name):
    element = []
    element.append(df.index.name + ' ' + 'datetime')
    series = df.dtypes
    for s in series.keys():
        data_type = 'double'
        element.append(s + ' ' + data_type)
    element.append('primary key ix_{}_{} ({})'.format(table_name, df.index.name, df.index.name))
    query = 'create table if not exists {} ({})'.format(table_name, ','.join(element))
#     print(query)
    engine.execute(query)
    
def insert_query(key, row, table_name):
    cols = [key]
    values = ["'" + row.name.strftime('%Y-%m-%d %H:%M:%S') + "'"]
    for col in row.index.tolist():
        cols.append(col)
        values.append(str(row[col]))
    query = 'insert into {} ({}) values ({})'.format(table_name, ','.join(cols), ','.join(values))
    engine.execute(query)
    
def insert_rows(df, table_name):
    for index, row in df.iterrows():
        try:
            insert_query(df.index.name, row, table_name)
        except:
            pass
  
def save_data(df, table_name):
    create_table(df, table_name)
    insert_rows(df, table_name)

# %%
def save_minute_candles(code, minute=1, count=1):
    table_name = get_table_name(code, minute)
    candles = get_minute_candles(code, minute=minute)
    i = 0
    while not candles.empty:
        save_data(candles, table_name)
        if len(candles) < 200:
            break
        if count:
            i += 1
            if i >= count:
                break
        next_time = get_utc(candles.iloc[0].name)
        print(next_time)
        candles = get_minute_candles(code, minute=minute, to=next_time)

# %%
codes = get_codes()

# %%
save_minute_candles(codes[2], minute=1, count=1000)
# Out:
# 2018-01-23 09:03:00
# /anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1050, "Table 'upbit_minutes_1_krw_xrp' already exists")
#   result = self._query(query)
# 2018-01-23 05:43:00
# 2018-01-23 02:23:00
# 2018-01-22 23:03:00
# 2018-01-22 19:43:00
# 2018-01-22 16:23:00
# 2018-01-22 13:03:00
# 2018-01-22 09:43:00
# 2018-01-22 06:23:00
# 2018-01-22 03:03:00
# 2018-01-21 23:43:00
# 2018-01-21 20:23:00
# 2018-01-21 16:28:00
# 2018-01-21 13:08:00
# 2018-01-21 09:48:00
# 2018-01-21 06:28:00
# 2018-01-21 03:08:00
# 2018-01-20 23:48:00
# 2018-01-20 20:28:00
# 2018-01-20 17:08:00
# 2018-01-20 13:48:00
# 2018-01-20 10:28:00
# 2018-01-20 07:08:00
# 2018-01-20 03:48:00
# 2018-01-20 00:28:00
# 2018-01-19 21:08:00
# 2018-01-19 17:48:00
# 2018-01-19 14:28:00
# 2018-01-19 11:08:00
# 2018-01-19 07:48:00
# 2018-01-19 04:28:00
# 2018-01-19 01:08:00
# 2018-01-18 21:48:00
# 2018-01-18 17:17:00
# 2018-01-18 13:57:00
# 2018-01-18 10:37:00
# 2018-01-18 07:17:00
# 2018-01-18 03:57:00
# 2018-01-18 00:37:00
# 2018-01-17 21:17:00
# 2018-01-17 17:57:00
# 2018-01-17 14:37:00
# 2018-01-17 11:17:00
# 2018-01-17 07:57:00
# 2018-01-17 04:37:00
# 2018-01-17 01:17:00
# 2018-01-16 21:57:00
# 2018-01-16 18:37:00
# 2018-01-16 15:17:00
# 2018-01-16 11:57:00
# 2018-01-16 08:37:00
# 2018-01-16 05:17:00
# 2018-01-16 01:57:00
# 2018-01-15 22:37:00
# 2018-01-15 19:17:00
# 2018-01-15 15:57:00
# 2018-01-15 12:37:00
# 2018-01-15 09:17:00
# 2018-01-15 05:57:00
# 2018-01-15 02:37:00
# 2018-01-14 23:17:00
# 2018-01-14 19:57:00
# 2018-01-14 16:37:00
# 2018-01-14 13:17:00
# 2018-01-14 09:57:00
# 2018-01-14 06:37:00
# 2018-01-14 03:17:00
# 2018-01-13 23:57:00
# 2018-01-13 20:37:00
# 2018-01-13 17:17:00
# 2018-01-13 13:57:00
# 2018-01-13 10:37:00
# 2018-01-13 07:17:00
# 2018-01-13 03:57:00
# 2018-01-13 00:37:00
# 2018-01-12 21:17:00
# 2018-01-12 17:57:00
# 2018-01-12 14:37:00
# 2018-01-12 11:17:00
# 2018-01-12 07:57:00
# 2018-01-12 04:37:00
# 2018-01-12 01:17:00
# 2018-01-11 21:57:00
# 2018-01-11 18:37:00
# 2018-01-11 15:17:00
# 2018-01-11 11:57:00
# 2018-01-11 08:37:00
# 2018-01-11 05:17:00
# 2018-01-11 01:57:00
# 2018-01-10 22:37:00
# 2018-01-10 19:17:00
# 2018-01-10 15:57:00
# 2018-01-10 12:37:00
# 2018-01-10 09:17:00
# 2018-01-10 05:57:00
# 2018-01-10 02:37:00
# 2018-01-09 23:17:00
# 2018-01-09 19:57:00
# 2018-01-09 16:37:00
# 2018-01-09 13:17:00
# 2018-01-09 09:57:00
# 2018-01-09 06:37:00
# 2018-01-09 03:17:00
# 2018-01-08 23:57:00
# 2018-01-08 20:37:00
# 2018-01-08 17:17:00
# 2018-01-08 13:57:00
# 2018-01-08 10:37:00
# 2018-01-08 07:17:00
# 2018-01-08 03:57:00
# 2018-01-08 00:37:00
# 2018-01-07 21:17:00
# 2018-01-07 17:57:00
# 2018-01-07 14:37:00
# 2018-01-07 11:17:00
# 2018-01-07 07:57:00
# 2018-01-07 04:37:00
# 2018-01-07 01:17:00
# 2018-01-06 21:57:00
# 2018-01-06 18:37:00
# 2018-01-06 15:17:00
# 2018-01-06 11:57:00
# 2018-01-06 08:37:00
# 2018-01-06 05:17:00
# 2018-01-06 01:57:00
# 2018-01-05 22:37:00
# 2018-01-05 19:17:00
# 2018-01-05 15:57:00
# 2018-01-05 12:37:00
# 2018-01-05 09:17:00
# 2018-01-05 05:57:00
# 2018-01-05 02:37:00
# 2018-01-04 23:16:00
# 2018-01-04 19:56:00
# 2018-01-04 16:36:00
# 2018-01-04 13:16:00
# 2018-01-04 09:56:00
# 2018-01-04 06:11:00
# 2018-01-04 02:46:00
# 2018-01-03 23:26:00
# 2018-01-03 20:06:00
# 2018-01-03 16:46:00
# 2018-01-03 13:26:00
# 2018-01-03 10:06:00
# 2018-01-03 06:46:00
# 2018-01-03 03:26:00
# 2018-01-03 00:06:00
# 2018-01-02 20:46:00
# 2018-01-02 17:26:00
# 2018-01-02 14:06:00
# 2018-01-02 10:46:00
# 2018-01-02 07:26:00
# 2018-01-02 04:06:00
# 2018-01-02 00:46:00
# 2018-01-01 21:26:00
# 2018-01-01 18:06:00
# 2018-01-01 14:46:00
# 2018-01-01 11:26:00
# 2018-01-01 08:06:00
# 2018-01-01 04:46:00
# 2018-01-01 01:26:00
# 2017-12-31 22:06:00
# 2017-12-31 18:46:00
# 2017-12-31 15:26:00
# 2017-12-31 12:06:00
# 2017-12-31 08:46:00
# 2017-12-31 05:26:00
# 2017-12-31 02:06:00
# 2017-12-30 22:46:00
# 2017-12-30 19:26:00
# 2017-12-30 16:06:00
# 2017-12-30 12:46:00
# 2017-12-30 09:26:00
# 2017-12-30 06:06:00
# 2017-12-30 02:46:00
# 2017-12-29 23:26:00
# 2017-12-29 20:06:00
# 2017-12-29 16:46:00
# 2017-12-29 13:26:00
# 2017-12-29 09:57:00
# 2017-12-29 06:37:00
# 2017-12-29 03:17:00
# 2017-12-28 23:57:00
# 2017-12-28 19:56:00
# 2017-12-28 16:36:00
# 2017-12-28 13:16:00
# 2017-12-28 09:56:00
# 2017-12-28 06:36:00
# 2017-12-28 03:16:00
# 2017-12-27 23:56:00
# 2017-12-27 20:36:00
# 2017-12-27 17:16:00
# 2017-12-27 13:56:00
# 2017-12-27 10:36:00
# 2017-12-27 07:16:00
# 2017-12-27 03:56:00
# 2017-12-27 00:36:00
# 2017-12-26 21:15:00
# 2017-12-26 17:36:00
# 2017-12-26 14:16:00
# 2017-12-26 10:56:00
# 2017-12-26 07:36:00
# 2017-12-26 04:16:00
# 2017-12-26 00:56:00
# 2017-12-25 21:36:00
# 2017-12-25 18:14:00
# 2017-12-25 14:54:00
# 2017-12-25 11:34:00
# 2017-12-25 08:14:00
# 2017-12-25 04:53:00
# 2017-12-25 01:33:00
# 2017-12-24 22:13:00
# 2017-12-24 18:53:00
# 2017-12-24 15:33:00
# 2017-12-24 12:13:00
# 2017-12-24 08:53:00
# 2017-12-24 05:33:00
# 2017-12-24 02:13:00
# 2017-12-23 22:53:00
# 2017-12-23 19:33:00
# 2017-12-23 16:13:00
# 2017-12-23 12:53:00
# 2017-12-23 09:33:00
# 2017-12-23 06:13:00
# 2017-12-23 02:53:00
# 2017-12-22 23:33:00
# 2017-12-22 20:13:00
# 2017-12-22 16:53:00
# 2017-12-22 13:33:00
# 2017-12-22 10:13:00
# 2017-12-22 06:53:00
# 2017-12-22 03:33:00
# 2017-12-22 00:13:00
# 2017-12-21 20:53:00
# 2017-12-21 17:33:00
# 2017-12-21 14:13:00
# 2017-12-21 10:53:00
# 2017-12-21 07:33:00
# 2017-12-21 04:13:00
# 2017-12-21 00:53:00
# 2017-12-20 21:33:00
# 2017-12-20 15:54:00
# 2017-12-20 12:34:00
# 2017-12-20 09:14:00
# 2017-12-20 05:54:00
# 2017-12-20 02:34:00
# 2017-12-19 23:14:00
# 2017-12-19 19:54:00
# 2017-12-19 16:34:00
# 2017-12-19 13:14:00
# 2017-12-19 09:54:00
# 2017-12-19 06:34:00
# 2017-12-19 03:14:00
# 2017-12-18 23:54:00
# 2017-12-18 20:34:00
# 2017-12-18 17:14:00
# 2017-12-18 13:54:00
# 2017-12-18 10:34:00
# 2017-12-18 07:14:00
# 2017-12-18 03:54:00
# 2017-12-18 00:34:00
# 2017-12-17 21:14:00
# 2017-12-17 17:54:00
# 2017-12-17 14:34:00
# 2017-12-17 11:06:00
# 2017-12-17 07:39:00
# 2017-12-17 04:15:00
# 2017-12-17 00:52:00
# 2017-12-16 21:32:00
# 2017-12-16 18:12:00
# 2017-12-16 14:52:00
# 2017-12-16 11:32:00
# 2017-12-16 08:12:00
# 2017-12-16 04:52:00
# 2017-12-16 01:32:00
# 2017-12-15 22:12:00
# 2017-12-15 18:52:00
# 2017-12-15 15:32:00
# 2017-12-15 12:12:00
# 2017-12-15 08:52:00
# 2017-12-15 05:32:00
# 2017-12-15 02:12:00
# 2017-12-14 22:52:00
# 2017-12-14 19:32:00
# 2017-12-14 16:12:00
# 2017-12-14 12:51:00
# 2017-12-14 09:31:00
# 2017-12-14 06:11:00
# 2017-12-14 02:51:00
# 2017-12-13 23:31:00
# 2017-12-13 20:11:00
# 2017-12-13 16:51:00
# 2017-12-13 13:31:00
# 2017-12-13 10:11:00
# 2017-12-13 06:51:00
# 2017-12-13 03:31:00
# 2017-12-13 00:09:00
# 2017-12-12 20:49:00
# 2017-12-12 17:29:00
# 2017-12-12 14:05:00
# 2017-12-12 10:45:00
# 2017-12-12 07:25:00
# 2017-12-12 04:05:00
# 2017-12-12 00:42:00
# 2017-12-11 20:57:00
# 2017-12-11 16:23:00
# 2017-12-11 12:53:00
# 2017-12-11 09:23:00
# 2017-12-11 05:50:00
# 2017-12-11 02:27:00
# 2017-12-10 23:04:00
# 2017-12-10 18:35:00
# 2017-12-10 14:55:00
# 2017-12-10 11:33:00
# 2017-12-10 08:02:00
# 2017-12-10 04:41:00
# 2017-12-10 01:21:00
# 2017-12-09 21:53:00
# 2017-12-09 18:13:00
# 2017-12-09 14:51:00
# 2017-12-09 11:29:00
# 2017-12-09 08:07:00
# 2017-12-09 04:44:00
# 2017-12-09 01:22:00
# 2017-12-08 22:02:00
# 2017-12-08 18:40:00
# 2017-12-08 15:19:00
# 2017-12-08 11:59:00
# 2017-12-08 08:39:00
# 2017-12-08 05:19:00
# 2017-12-08 01:59:00
# 2017-12-07 22:30:00
# 2017-12-07 17:57:00
# 2017-12-07 14:23:00
# 2017-12-07 10:51:00
# 2017-12-07 07:14:00
# 2017-12-07 03:44:00
# 2017-12-07 00:21:00
# 2017-12-06 20:53:00
# 2017-12-06 17:05:00
# 2017-12-06 07:56:00
# 2017-12-06 04:34:00
# 2017-12-06 01:13:00
# 2017-12-05 21:52:00
# 2017-12-05 17:54:00
# 2017-12-05 14:20:00
# 2017-12-05 10:53:00
# 2017-12-05 07:22:00
# 2017-12-05 03:55:00
# 2017-12-05 00:17:00
# 2017-12-04 20:24:00
# 2017-12-04 15:31:00
# 2017-12-04 12:10:00
# 2017-12-04 08:43:00
# 2017-12-04 05:23:00
# 2017-12-04 02:03:00
# 2017-12-03 22:27:00
# 2017-12-03 17:47:00
# 2017-12-03 14:05:00
# 2017-12-03 10:45:00
# 2017-12-03 07:25:00
# 2017-12-03 04:01:00
# 2017-12-03 00:37:00
# 2017-12-02 20:34:00
# 2017-12-02 15:48:00
# 2017-12-02 12:25:00
# 2017-12-02 09:00:00
# 2017-12-02 05:36:00
# 2017-12-02 02:13:00
# 2017-12-01 22:48:00
# 2017-12-01 18:01:00
# 2017-12-01 14:35:00
# 2017-12-01 11:15:00
# 2017-12-01 07:41:00
# 2017-12-01 04:03:00
# 2017-12-01 00:34:00
# 2017-11-30 21:12:00
# 2017-11-30 17:41:00
# 2017-11-30 14:13:00
# 2017-11-30 10:52:00
# 2017-11-30 07:26:00
# 2017-11-30 04:05:00
# 2017-11-30 00:44:00
# 2017-11-29 20:53:00
# 2017-11-29 17:05:00
# 2017-11-29 13:43:00
# 2017-11-29 10:23:00
# 2017-11-29 07:01:00
# 2017-11-29 03:41:00
# 2017-11-29 00:21:00
# 2017-11-28 21:00:00
# 2017-11-28 17:10:00
# 2017-11-28 13:50:00
# 2017-11-28 10:30:00
# 2017-11-28 06:47:00
# 2017-11-28 03:26:00
# 2017-11-28 00:05:00
# 2017-11-27 19:36:00
# 2017-11-27 14:44:00
# 2017-11-27 11:17:00
# 2017-11-27 07:55:00
# 2017-11-27 04:24:00
# 2017-11-27 00:42:00
# 2017-11-26 19:45:00
# 2017-11-26 15:11:00
# 2017-11-26 11:31:00
# 2017-11-26 07:55:00
# 2017-11-26 03:58:00
# 2017-11-26 00:23:00
# 2017-11-25 19:23:00
# 2017-11-25 15:09:00
# 2017-11-25 11:32:00
# 2017-11-25 07:43:00
# 2017-11-25 04:07:00
# 2017-11-25 00:39:00
# 2017-11-24 20:21:00
# 2017-11-24 15:36:00
# 2017-11-24 12:07:00
# 2017-11-24 08:37:00
# 2017-11-24 05:09:00
# 2017-11-24 01:37:00
# 2017-11-23 22:00:00
# 2017-11-23 17:35:00
# 2017-11-23 13:50:00
# 2017-11-23 10:03:00
# 2017-11-23 06:16:00
# 2017-11-23 02:14:00
# 2017-11-22 22:09:00
# 2017-11-22 17:03:00
# 2017-11-22 13:09:00
# 2017-11-22 08:24:00
# 2017-11-22 03:23:00
# 2017-11-21 22:29:00
# 2017-11-21 14:55:00
# 2017-11-21 10:36:00
# 2017-11-21 06:14:00
# 2017-11-21 02:48:00
# 2017-11-20 23:13:00
# 2017-11-20 18:05:00
# 2017-11-20 13:59:00
# 2017-11-20 10:27:00
# 2017-11-20 06:42:00
# 2017-11-20 03:03:00
# 2017-11-19 21:52:00
# 2017-11-19 14:47:00
# 2017-11-19 11:06:00
# 2017-11-19 07:00:00
# 2017-11-19 03:12:00
# 2017-11-18 23:06:00
# 2017-11-18 18:09:00
# 2017-11-18 13:45:00
# 2017-11-18 10:02:00
# 2017-11-18 06:20:00
# 2017-11-18 02:32:00
# 2017-11-17 22:46:00
# 2017-11-17 18:28:00
# 2017-11-17 14:23:00
# 2017-11-17 10:59:00
# 2017-11-17 07:28:00
# 2017-11-17 04:01:00
# 2017-11-17 00:35:00
# 2017-11-16 21:09:00
# 2017-11-16 17:30:00
# 2017-11-16 14:09:00
# 2017-11-16 10:26:00
# 2017-11-16 06:10:00
# 2017-11-16 02:16:00
# 2017-11-15 21:56:00
# 2017-11-15 16:30:00
# 2017-11-15 12:28:00
# 2017-11-15 07:57:00
# 2017-11-15 04:02:00
# 2017-11-14 23:46:00
# 2017-11-14 18:30:00
# 2017-11-14 13:55:00
# 2017-11-14 10:12:00
# 2017-11-14 06:50:00
# 2017-11-14 03:22:00
# 2017-11-14 00:02:00
# 2017-11-13 20:42:00
# 2017-11-13 17:22:00
# 2017-11-13 14:02:00
# 2017-11-13 10:09:00
# 2017-11-13 06:07:00
# 2017-11-12 23:11:00
# 2017-11-12 15:17:00
# 2017-11-11 21:58:00
# 2017-11-11 14:04:00
# 2017-11-11 05:39:00
# 2017-11-10 21:39:00
# 2017-11-10 13:44:00
# 2017-11-10 05:36:00
# 2017-11-09 21:24:00
# 2017-11-09 13:19:00
# 2017-11-09 05:01:00
# 2017-11-08 20:53:00
# 2017-11-08 12:52:00
# 2017-11-08 04:24:00
# 2017-11-07 20:20:00
# 2017-11-07 12:19:00
# 2017-11-07 04:18:00
# 2017-11-05 08:21:00
# 2017-11-04 11:36:00
# 2017-11-03 14:51:00
# 2017-11-02 18:05:00
# 2017-11-01 21:13:00
# 2017-10-31 23:41:00
# 2017-10-30 23:38:00
# 2017-10-30 06:59:00
# 2017-10-29 19:29:00
# 2017-10-28 20:49:00
# 2017-10-27 22:38:00
# 2017-10-27 02:09:00
# 2017-10-26 05:39:00
# 2017-10-25 08:50:00
# 2017-10-24 12:25:00
# 2017-10-20 06:12:00
# 2017-10-19 09:48:00
# 2017-10-18 05:16:00
# 2017-10-17 21:36:00
# 2017-10-17 14:04:00
# 2017-10-17 06:25:00
# 2017-10-16 20:50:00
# 2017-10-16 11:22:00
# 2017-10-16 01:41:00
# 2017-10-15 16:20:00
# 2017-10-15 07:01:00
# 2017-10-14 21:42:00
# 2017-10-14 12:24:00
# 2017-10-14 03:03:00
# 2017-10-13 17:45:00
# 2017-10-13 08:21:00
# 2017-10-12 22:56:00
# 2017-10-12 13:38:00
# 2017-10-12 04:12:00
# 2017-10-11 18:50:00
# 2017-10-11 09:30:00
# 2017-10-11 00:01:00
# 2017-10-10 14:48:00
# 2017-10-10 05:26:00
# 2017-10-09 20:05:00
# 2017-10-09 10:50:00
# 2017-10-09 01:35:00
# 2017-10-08 16:17:00
# 2017-10-08 07:03:00
# 2017-10-07 21:51:00
# 2017-10-07 12:38:00
# 2017-10-07 03:25:00
# 2017-10-06 18:13:00
# 2017-10-06 08:59:00
# 2017-10-05 22:27:00
# 2017-10-05 12:15:00
# 2017-10-05 02:05:00
# 2017-10-04 15:49:00
# 2017-10-04 05:51:00
# 2017-10-03 19:15:00
# 2017-10-03 09:14:00
# 2017-10-02 23:59:00
# 2017-10-02 14:52:00
# 2017-10-02 05:40:00
# 2017-10-01 20:32:00
# 2017-10-01 11:24:00
# 2017-10-01 02:10:00
# 2017-09-30 17:03:00
# 2017-09-30 07:55:00
# 2017-09-29 22:44:00
# 2017-09-29 13:37:00
# 2017-09-29 04:24:00
# 2017-09-28 19:12:00
# 2017-09-28 08:37:00
# 2017-09-27 23:22:00
# 2017-09-27 14:15:00
# 2017-09-27 04:21:00
# 2017-09-26 19:01:00
# 2017-09-26 09:48:00
# 2017-09-26 00:32:00
# 2017-09-25 13:55:00

# %%
df = read_data(get_table_name(codes[0], 30), '2017-12-01')
# Out:
# select * from upbit_minutes_30_krw_btc where dt_kst >= '2017-12-01'

# %%
def calculate_candles(df):
    df['mid'] = (df['open'] + df['close']) / 2

    eye = eye_balance(df)
    df['eye_base'] = eye['base']
    df['eye_trans'] = eye['trans']
    df['eye_fore1'] = eye['fore1']
    df['eye_fore2'] = eye['fore2']
    df['eye_fore_diff'] = (df['eye_fore1'] - df['eye_fore2']) / df['eye_fore1']
    df['mid_eye_fore1'] = (df['mid'] - df['eye_fore1']) / df['mid']
    df['mid_eye_fore2'] = (df['mid'] - df['eye_fore2']) / df['mid']
    conditions = [
        (df['mid_eye_fore1'] > 0) & (df['mid_eye_fore2'] > 0),
        (df['mid_eye_fore1'] < 0) & (df['mid_eye_fore2'] < 0)]
    choices = ['over', 'under']
    df['mid_eye_fore'] = np.select(conditions, choices, default='middle')
    df['mid_eye_fore_pre'] = df['mid_eye_fore'].shift(1)
    df['eye_trans_base'] = np.where(df['eye_trans'] > df['eye_base'], 'over', 'under')

    df['low_point'] = (df['low'] < df['low'].shift(-1)) & (df['low'] < df['low'].shift(1))
    df['high_point'] = (df['high'] > df['high'].shift(-1)) & (df['high'] > df['high'].shift(1))

    df['ma40'] = sma(df, 40)
    df['mid_ma40'] = np.where(df['mid'] > df['ma40'], 'over', 'under')
    df['ema112'] = sma(df, 112)
    df['mid_ema112'] = np.where(df['mid'] > df['ema112'], 'over', 'under')

# %%
df[(df['mid_eye_fore']=='over') & (df['mid_eye_fore_pre']!='over')][['low','high','mid','eye_fore1','eye_fore2','mid_eye_fore','mid_eye_fore_pre','mid_ma40','eye_trans_base','mid_ema112','high_point','low_point']]
# Out:
#                             low        high         mid   eye_fore1  \
# dt_kst
# 2017-12-02 14:00:00  12826000.0  12890000.0  12858000.0  12122750.0
# 2017-12-03 04:30:00  12814000.0  12864000.0  12839000.0  12814750.0
# 2017-12-11 01:00:00  17370000.0  17769000.0  17569500.0  16075000.0
# 2017-12-12 22:30:00  19240000.0  19350000.0  19295000.0  19170000.0
# 2017-12-13 01:00:00  19078000.0  19180000.0  19129000.0  19111500.0
# 2017-12-13 03:00:00  19115000.0  19482000.0  19298500.0  19205500.0
# 2017-12-13 23:00:00  18654000.0  18765000.0  18709500.0  18385250.0
# 2017-12-14 10:00:00  18400000.0  18640000.0  18520000.0  18511750.0
# 2017-12-14 17:00:00  18296000.0  19312000.0  18804000.0  18372000.0
# 2017-12-15 03:30:00  18352000.0  18760000.0  18556000.0  18335500.0
# 2017-12-15 09:30:00  18629000.0  19277000.0  18953000.0  18755250.0
# 2017-12-16 01:00:00  19857000.0  20214000.0  20035500.0  19991250.0
# 2017-12-16 04:00:00  20180000.0  20495000.0  20337500.0  20238000.0
# 2017-12-16 15:30:00  20118000.0  20554000.0  20336000.0  20286000.0
# 2017-12-16 20:30:00  20270000.0  20490000.0  20380000.0  20281750.0
# 2017-12-18 14:00:00  21992000.0  22250000.0  22121000.0  22040000.0
# 2017-12-18 16:00:00  21911000.0  22116000.0  22013500.0  21987000.0
# 2017-12-18 20:30:00  21882000.0  22189000.0  22035500.0  21766000.0
# 2017-12-19 00:00:00  21914000.0  22203000.0  22058500.0  21590750.0
# 2017-12-19 08:00:00  21860000.0  22150000.0  22005000.0  21702750.0
# 2017-12-20 19:30:00  22000000.0  22480000.0  22240000.0  21656500.0
# 2017-12-21 02:30:00  22069000.0  22583000.0  22326000.0  21514250.0
# 2017-12-21 04:00:00  21947000.0  22176000.0  22061500.0  21631500.0
# 2017-12-23 07:30:00  19774000.0  20940000.0  20357000.0  19378750.0
# 2017-12-23 12:00:00  19694000.0  20200000.0  19947000.0  18527250.0
# 2017-12-23 19:30:00  19297000.0  19871000.0  19584000.0  18733000.0
# 2017-12-24 12:30:00  19755000.0  20129000.0  19942000.0  19864500.0
# 2017-12-24 15:00:00  19831000.0  20090000.0  19960500.0  19914500.0
# 2017-12-25 21:30:00  19745000.0  19950000.0  19847500.0  19218250.0
# 2017-12-26 00:30:00  19499000.0  19660000.0  19579500.0  19353500.0
# ...                         ...         ...         ...         ...
# 2017-12-31 23:30:00  18527000.0  18722000.0  18624500.0  18567000.0
# 2018-01-02 09:30:00  18905000.0  19079000.0  18992000.0  18976500.0
# 2018-01-02 14:30:00  18830000.0  18949000.0  18889500.0  18726500.0
# 2018-01-03 22:30:00  20260000.0  20496000.0  20378000.0  20326250.0
# 2018-01-04 06:30:00  20542000.0  20911000.0  20726500.0  20646500.0
# 2018-01-04 07:30:00  20669000.0  20899000.0  20784000.0  20764750.0
# 2018-01-04 19:00:00  20500000.0  21410000.0  20955000.0  20490250.0
# 2018-01-05 02:30:00  21411000.0  21645000.0  21528000.0  21450750.0
# 2018-01-07 07:00:00  25936000.0  26597000.0  26266500.0  25971000.0
# 2018-01-07 15:00:00  26343000.0  26650000.0  26496500.0  25223000.0
# 2018-01-07 19:30:00  26351000.0  26540000.0  26445500.0  25668250.0
# 2018-01-08 15:00:00  25750000.0  26299000.0  26024500.0  25595500.0
# 2018-01-09 10:30:00  25161000.0  25786000.0  25473500.0  25343500.0
# 2018-01-12 02:00:00  19500000.0  19833000.0  19666500.0  18090250.0
# 2018-01-12 08:30:00  18800000.0  19499000.0  19149500.0  18865750.0
# 2018-01-12 10:00:00  18590000.0  18900000.0  18745000.0  18699750.0
# 2018-01-12 12:30:00  18401000.0  18744000.0  18572500.0  18536250.0
# 2018-01-12 14:30:00  18742000.0  19499000.0  19120500.0  18822750.0
# 2018-01-12 19:00:00  19444000.0  19853000.0  19648500.0  19307750.0
# 2018-01-15 23:00:00  19661000.0  19980000.0  19820500.0  19235500.0
# 2018-01-16 01:00:00  19354000.0  19620000.0  19487000.0  19235500.0
# 2018-01-16 05:00:00  19320000.0  19547000.0  19433500.0  19243500.0
# 2018-01-18 06:30:00  14732000.0  15500000.0  15116000.0  13496250.0
# 2018-01-18 08:00:00  13950000.0  14850000.0  14400000.0  13354000.0
# 2018-01-19 05:00:00  14636000.0  15198000.0  14917000.0  14676250.0
# 2018-01-19 15:00:00  14607000.0  14730000.0  14668500.0  14602250.0
# 2018-01-19 17:00:00  14515000.0  15000000.0  14757500.0  14582000.0
# 2018-01-19 21:00:00  14919000.0  15120000.0  15019500.0  14885000.0
# 2018-01-20 00:30:00  14976000.0  15293000.0  15134500.0  14832500.0
# 2018-01-21 12:00:00  16300000.0  16490000.0  16395000.0  16371500.0
#
#                       eye_fore2 mid_eye_fore mid_eye_fore_pre mid_ma40  \
# dt_kst
# 2017-12-02 14:00:00  11515000.0         over           middle     over
# 2017-12-03 04:30:00  12245000.0         over           middle    under
# 2017-12-11 01:00:00  16957500.0         over           middle     over
# 2017-12-12 22:30:00  18729500.0         over           middle    under
# 2017-12-13 01:00:00  19105000.0         over           middle    under
# 2017-12-13 03:00:00  19059500.0         over            under     over
# 2017-12-13 23:00:00  18464000.0         over            under    under
# 2017-12-14 10:00:00  18430500.0         over           middle     over
# 2017-12-14 17:00:00  18430500.0         over            under     over
# 2017-12-15 03:30:00  18549500.0         over           middle     over
# 2017-12-15 09:30:00  18656000.0         over           middle     over
# 2017-12-16 01:00:00  19829500.0         over           middle     over
# 2017-12-16 04:00:00  19829500.0         over           middle     over
# 2017-12-16 15:30:00  19934000.0         over           middle     over
# 2017-12-16 20:30:00  19978500.0         over           middle     over
# 2017-12-18 14:00:00  21933000.0         over           middle     over
# 2017-12-18 16:00:00  22010500.0         over           middle     over
# 2017-12-18 20:30:00  21980500.0         over           middle     over
# 2017-12-19 00:00:00  21970500.0         over           middle     over
# 2017-12-19 08:00:00  21970500.0         over           middle     over
# 2017-12-20 19:30:00  22095500.0         over           middle     over
# 2017-12-21 02:30:00  22095500.0         over           middle     over
# 2017-12-21 04:00:00  21790000.0         over           middle    under
# 2017-12-23 07:30:00  20285000.0         over           middle     over
# 2017-12-23 12:00:00  19737500.0         over           middle     over
# 2017-12-23 19:30:00  19472500.0         over           middle     over
# 2017-12-24 12:30:00  18522500.0         over           middle    under
# 2017-12-24 15:00:00  19020000.0         over           middle    under
# 2017-12-25 21:30:00  19809500.0         over           middle     over
# 2017-12-26 00:30:00  19399500.0         over           middle     over
# ...                         ...          ...              ...      ...
# 2017-12-31 23:30:00  18598500.0         over           middle    under
# 2018-01-02 09:30:00  18910000.0         over            under     over
# 2018-01-02 14:30:00  18855000.0         over           middle     over
# 2018-01-03 22:30:00  20115000.0         over           middle    under
# 2018-01-04 06:30:00  20222500.0         over           middle     over
# 2018-01-04 07:30:00  20222500.0         over           middle     over
# 2018-01-04 19:00:00  20424500.0         over            under    under
# 2018-01-05 02:30:00  20860000.0         over           middle     over
# 2018-01-07 07:00:00  25798000.0         over           middle     over
# 2018-01-07 15:00:00  26425500.0         over           middle     over
# 2018-01-07 19:30:00  26425500.0         over           middle     over
# 2018-01-08 15:00:00  25963000.0         over           middle     over
# 2018-01-09 10:30:00  25283500.0         over            under     over
# 2018-01-12 02:00:00  19152000.0         over           middle    under
# 2018-01-12 08:30:00  18492000.0         over           middle    under
# 2018-01-12 10:00:00  18369500.0         over           middle    under
# 2018-01-12 12:30:00  18183500.0         over           middle    under
# 2018-01-12 14:30:00  18183500.0         over           middle    under
# 2018-01-12 19:00:00  18102000.0         over           middle     over
# 2018-01-15 23:00:00  19715000.0         over           middle     over
# 2018-01-16 01:00:00  19344000.0         over           middle     over
# 2018-01-16 05:00:00  19137000.0         over           middle     over
# 2018-01-18 06:30:00  14667000.0         over           middle     over
# 2018-01-18 08:00:00  14268500.0         over           middle     over
# 2018-01-19 05:00:00  14135500.0         over           middle     over
# 2018-01-19 15:00:00  14135500.0         over           middle    under
# 2018-01-19 17:00:00  14390000.0         over           middle     over
# 2018-01-19 21:00:00  14935000.0         over           middle     over
# 2018-01-20 00:30:00  15010000.0         over           middle     over
# 2018-01-21 12:00:00  15989000.0         over           middle    under
#
#                     eye_trans_base mid_ema112  high_point  low_point
# dt_kst
# 2017-12-02 14:00:00           over      under       False      False
# 2017-12-03 04:30:00          under      under       False      False
# 2017-12-11 01:00:00           over      under       False      False
# 2017-12-12 22:30:00           over       over       False      False
# 2017-12-13 01:00:00          under       over       False      False
# 2017-12-13 03:00:00          under       over        True      False
# 2017-12-13 23:00:00           over      under       False      False
# 2017-12-14 10:00:00          under      under       False      False
# 2017-12-14 17:00:00           over       over        True      False
# 2017-12-15 03:30:00          under      under        True       True
# 2017-12-15 09:30:00           over       over        True      False
# 2017-12-16 01:00:00           over       over        True      False
# 2017-12-16 04:00:00          under       over        True      False
# 2017-12-16 15:30:00           over       over       False      False
# 2017-12-16 20:30:00           over       over       False      False
# 2017-12-18 14:00:00          under       over       False      False
# 2017-12-18 16:00:00           over       over       False      False
# 2017-12-18 20:30:00           over       over       False      False
# 2017-12-19 00:00:00           over       over        True      False
# 2017-12-19 08:00:00          under       over        True      False
# 2017-12-20 19:30:00           over       over        True      False
# 2017-12-21 02:30:00           over       over        True      False
# 2017-12-21 04:00:00           over      under       False      False
# 2017-12-23 07:30:00           over      under        True      False
# 2017-12-23 12:00:00           over      under       False      False
# 2017-12-23 19:30:00          under      under       False      False
# 2017-12-24 12:30:00          under       over        True      False
# 2017-12-24 15:00:00          under       over       False      False
# 2017-12-25 21:30:00           over       over        True      False
# 2017-12-26 00:30:00           over      under        True      False
# ...                            ...        ...         ...        ...
# 2017-12-31 23:30:00          under      under       False      False
# 2018-01-02 09:30:00           over       over        True      False
# 2018-01-02 14:30:00           over       over       False      False
# 2018-01-03 22:30:00          under       over       False      False
# 2018-01-04 06:30:00           over       over        True      False
# 2018-01-04 07:30:00           over       over       False      False
# 2018-01-04 19:00:00          under       over        True      False
# 2018-01-05 02:30:00           over       over       False      False
# 2018-01-07 07:00:00           over       over       False      False
# 2018-01-07 15:00:00          under       over       False      False
# 2018-01-07 19:30:00          under       over        True      False
# 2018-01-08 15:00:00          under       over        True      False
# 2018-01-09 10:30:00           over      under        True      False
# 2018-01-12 02:00:00           over      under       False      False
# 2018-01-12 08:30:00          under      under        True      False
# 2018-01-12 10:00:00          under      under       False      False
# 2018-01-12 12:30:00          under      under       False      False
# 2018-01-12 14:30:00           over      under       False      False
# 2018-01-12 19:00:00           over      under       False      False
# 2018-01-15 23:00:00           over      under        True      False
# 2018-01-16 01:00:00           over      under       False       True
# 2018-01-16 05:00:00           over      under       False      False
# 2018-01-18 06:30:00           over      under        True      False
# 2018-01-18 08:00:00           over      under       False      False
# 2018-01-19 05:00:00           over       over       False      False
# 2018-01-19 15:00:00          under       over       False      False
# 2018-01-19 17:00:00          under       over       False      False
# 2018-01-19 21:00:00           over       over        True      False
# 2018-01-20 00:30:00           over       over       False      False
# 2018-01-21 12:00:00          under       over        True      False
#
# [64 rows x 12 columns]

# %%
df_low_point = df[df['low_point']]
df_high_point = df[df['high_point']]

# %%
def is_good_point(d):
    if d.mid_eye_fore == 'over' and d.mid_ma40 == 'over' and d.close > d.open:
        return True
    return False

def get_point(df):
    buy_point = None
    for i in range(1, 200):
        d = df.iloc[-1*i]
        if d.mid_eye_fore != 'over' and buy_point is not None:
            break
        elif is_good_point(d):
            buy_point = d
    if buy_point is not None:
        print('Buy:', buy_point.name, d.close)

        df_sell = df[buy_point.name:]
        sell_point = {}
        pre_row = None
        for index, row in df_sell.iterrows():
            if index == buy_point.name:
                continue
            if row.mid_ma40 == 'under':
                key = '40이평'
                if key not in sell_point:
                    sell_point[key] = str(row.name) + ', ' + str(row.close)
            if (row.eye_trans_base == 'under') and row.close < row.eye_trans and pre_row is not None and pre_row.close > row.close:
                key = '일목역전'
                if key not in sell_point:
                    sell_point[key] = str(row.name) + ', ' + str(row.close)
            if (row.low < row.eye_fore1) and row.low < row.eye_fore2:
                key = '구름대깨짐'
                if key not in sell_point:
                    sell_point[key] = str(row.name) + ', ' + str(row.close)                
            pre_row = row
        print('Sell:', sell_point)

# %%
get_point(df)
# Out:
# Buy: 2018-01-19 21:00:00
# Sell: {'일목역전': '2018-01-21 00:30:00, 16367000.0', '40이평': '2018-01-21 09:00:00, 16326000.0'}

# %%
for code in codes[:30]:
    df = get_minute_candles(code, 30)
    calculate_candles(df)
    print('#' + code)
    get_point(df)
# Out:
# #CRIX.UPBIT.KRW-BTC
# Buy: 2018-01-20 05:30:00 15110000.0
# Sell: {'40이평': '2018-01-21 09:00:00, 16326000.0', '일목역전': '2018-01-21 09:30:00, 15700000.0', '구름대깨짐': '2018-01-21 09:30:00, 15700000.0'}
# #CRIX.UPBIT.KRW-ADA
# Buy: 2018-01-20 07:00:00 856.0
# Sell: {'일목역전': '2018-01-21 00:00:00, 898.0', '구름대깨짐': '2018-01-21 09:00:00, 896.0', '40이평': '2018-01-21 09:30:00, 867.0'}
# #CRIX.UPBIT.KRW-QTUM
# Buy: 2018-01-20 05:30:00 50860.0
# Sell: {'40이평': '2018-01-21 13:30:00, 56180.0', '일목역전': '2018-01-21 13:30:00, 56180.0', '구름대깨짐': '2018-01-21 14:00:00, 58600.0'}
# #CRIX.UPBIT.KRW-XRP
# #CRIX.UPBIT.KRW-SNT
# Buy: 2018-01-20 05:00:00 432.0
# Sell: {'일목역전': '2018-01-20 09:30:00, 437.0', '40이평': '2018-01-20 21:00:00, 442.0', '구름대깨짐': '2018-01-21 09:00:00, 436.0'}
# #CRIX.UPBIT.KRW-ETH
# Buy: 2018-01-20 05:30:00 1375000.0
# Sell: {'일목역전': '2018-01-20 06:30:00, 1367500.0', '40이평': '2018-01-21 09:30:00, 1402500.0', '구름대깨짐': '2018-01-21 09:30:00, 1402500.0'}
# #CRIX.UPBIT.KRW-NEO
# Buy: 2018-01-21 00:30:00 187900.0
# Sell: {'40이평': '2018-01-21 09:30:00, 179000.0', '일목역전': '2018-01-21 09:30:00, 179000.0', '구름대깨짐': '2018-01-21 09:30:00, 179000.0'}
# #CRIX.UPBIT.KRW-SBD
# Buy: 2018-01-22 07:00:00 9700.0
# Sell: {'구름대깨짐': '2018-01-22 07:30:00, 9730.0', '40이평': '2018-01-22 10:30:00, 8720.0', '일목역전': '2018-01-22 12:00:00, 8700.0'}
# #CRIX.UPBIT.KRW-MER
# Buy: 2018-01-20 04:30:00 840.0
# Sell: {'일목역전': '2018-01-20 20:30:00, 994.0', '40이평': '2018-01-21 00:30:00, 991.0', '구름대깨짐': '2018-01-21 09:30:00, 901.0'}
# #CRIX.UPBIT.KRW-XLM
# Buy: 2018-01-21 06:00:00 692.0
# Sell: {'40이평': '2018-01-21 09:00:00, 672.0', '구름대깨짐': '2018-01-21 09:00:00, 672.0', '일목역전': '2018-01-21 09:30:00, 640.0'}
# #CRIX.UPBIT.KRW-STEEM
# Buy: 2018-01-21 06:30:00 7080.0
# Sell: {'40이평': '2018-01-21 09:30:00, 6500.0', '일목역전': '2018-01-21 09:30:00, 6500.0', '구름대깨짐': '2018-01-21 09:30:00, 6500.0'}
# #CRIX.UPBIT.KRW-ARDR
# #CRIX.UPBIT.KRW-BTG
# Buy: 2018-01-21 04:00:00 302050.0
# Sell: {'40이평': '2018-01-21 09:00:00, 290000.0', '구름대깨짐': '2018-01-21 09:00:00, 290000.0', '일목역전': '2018-01-21 09:30:00, 272500.0'}
# #CRIX.UPBIT.KRW-BCC
# Buy: 2018-01-20 10:30:00 2368000.0
# Sell: {'40이평': '2018-01-21 09:30:00, 2403000.0', '일목역전': '2018-01-21 09:30:00, 2403000.0', '구름대깨짐': '2018-01-21 09:30:00, 2403000.0'}
# #CRIX.UPBIT.KRW-XEM
# Buy: 2018-01-20 05:30:00 1415.0
# Sell: {'일목역전': '2018-01-20 06:30:00, 1410.0', '40이평': '2018-01-21 09:30:00, 1420.0', '구름대깨짐': '2018-01-21 09:30:00, 1420.0'}
# #CRIX.UPBIT.KRW-EMC2
# Buy: 2018-01-20 04:30:00 850.0
# Sell: {'일목역전': '2018-01-20 22:00:00, 978.0', '40이평': '2018-01-21 04:00:00, 957.0', '구름대깨짐': '2018-01-21 09:30:00, 900.0'}
# #CRIX.UPBIT.KRW-TIX
# Buy: 2018-01-20 05:00:00 1645.0
# Sell: {'일목역전': '2018-01-21 04:00:00, 1900.0', '40이평': '2018-01-21 09:30:00, 1715.0', '구름대깨짐': '2018-01-21 09:30:00, 1715.0'}
# #CRIX.UPBIT.KRW-POWR
# Buy: 2018-01-21 03:30:00 1665.0
# Sell: {'40이평': '2018-01-21 09:00:00, 1605.0', '구름대깨짐': '2018-01-21 09:00:00, 1605.0', '일목역전': '2018-01-21 09:30:00, 1500.0'}
# #CRIX.UPBIT.KRW-ETC
# Buy: 2018-01-20 05:30:00 41700.0
# Sell: {'일목역전': '2018-01-20 20:30:00, 42810.0', '40이평': '2018-01-21 09:30:00, 42040.0', '구름대깨짐': '2018-01-21 09:30:00, 42040.0'}
# #CRIX.UPBIT.KRW-KMD
# Buy: 2018-01-20 04:30:00 8810.0
# Sell: {'일목역전': '2018-01-20 06:30:00, 8850.0', '40이평': '2018-01-21 09:00:00, 10220.0', '구름대깨짐': '2018-01-21 09:30:00, 9830.0'}
# #CRIX.UPBIT.KRW-STRAT
# Buy: 2018-01-20 05:00:00 19660.0
# Sell: {'40이평': '2018-01-21 09:30:00, 19220.0', '일목역전': '2018-01-21 09:30:00, 19220.0', '구름대깨짐': '2018-01-21 09:30:00, 19220.0'}
# #CRIX.UPBIT.KRW-OMG
# Buy: 2018-01-21 03:30:00 25570.0
# Sell: {'40이평': '2018-01-21 09:00:00, 25150.0', '일목역전': '2018-01-21 09:30:00, 23430.0', '구름대깨짐': '2018-01-21 09:30:00, 23430.0'}
# #CRIX.UPBIT.KRW-REP
# Buy: 2018-01-20 04:30:00 99910.0
# Sell: {'일목역전': '2018-01-20 15:30:00, 108550.0', '40이평': '2018-01-21 13:30:00, 112750.0', '구름대깨짐': '2018-01-21 16:30:00, 113750.0'}
# #CRIX.UPBIT.KRW-GRS
# Buy: 2018-01-20 05:30:00 1465.0
# Sell: {'일목역전': '2018-01-20 22:00:00, 1570.0', '40이평': '2018-01-21 04:30:00, 1575.0', '구름대깨짐': '2018-01-21 09:30:00, 1450.0'}
# #CRIX.UPBIT.KRW-STORJ
# Buy: 2018-01-20 06:30:00 2330.0
# Sell: {'일목역전': '2018-01-20 19:00:00, 2435.0', '40이평': '2018-01-20 22:30:00, 2410.0', '구름대깨짐': '2018-01-21 09:00:00, 2310.0'}
# #CRIX.UPBIT.KRW-WAVES
# Buy: 2018-01-20 04:00:00 11330.0
# Sell: {'일목역전': '2018-01-20 07:30:00, 11330.0', '40이평': '2018-01-21 09:00:00, 12090.0', '구름대깨짐': '2018-01-21 09:30:00, 11420.0'}
# #CRIX.UPBIT.KRW-MTL
# Buy: 2018-01-21 03:00:00 7305.0
# Sell: {'일목역전': '2018-01-21 14:30:00, 8180.0', '40이평': '2018-01-21 18:00:00, 7625.0', '구름대깨짐': '2018-01-21 22:00:00, 7815.0'}
# #CRIX.UPBIT.KRW-ARK
# Buy: 2018-01-21 11:00:00 9150.0
# Sell: {'일목역전': '2018-01-21 12:30:00, 9110.0', '40이평': '2018-01-21 13:00:00, 8950.0', '구름대깨짐': '2018-01-21 13:00:00, 8950.0'}
# #CRIX.UPBIT.KRW-XMR
# Buy: 2018-01-20 04:30:00 437000.0
# Sell: {'일목역전': '2018-01-21 06:30:00, 507900.0', '40이평': '2018-01-21 08:00:00, 507000.0', '구름대깨짐': '2018-01-21 10:00:00, 488500.0'}
# #CRIX.UPBIT.KRW-LTC
# Buy: 2018-01-20 04:30:00 252950.0
# Sell: {'일목역전': '2018-01-20 20:30:00, 258200.0', '40이평': '2018-01-21 09:30:00, 259200.0', '구름대깨짐': '2018-01-21 09:30:00, 259200.0'}
